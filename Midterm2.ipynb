# %% [markdown]
# # Midterm 2 coding Questions Total : 60
# ### 50 minute
# ### Name-
# After complition submit it on Moodle using `GitHub` with in the assigned time

# %% [markdown]
# ### Question 1. Create a list of random numbers between 3 to 15.  Cube each numbers and append those to a new list
# - 5 points

# %% [markdown]
# ### Question 2. Create a list of 10 random integer numbers using build in random module and find out minimum , maximum and total of the list.
# * 5 + 3 = 8 points

# %% [markdown]
# ### Question 3. Print `day` and `300` from the new_list
# new_list= [10, ['new', 300, [[3.141, 20],  345 ]], 'day' ]
# * 2 + 2 = 4 points

# %% [markdown]
# ### Question 4.  College=("Bellarmine", "2001 Neuburg RD")
# Print the `name` of the College.
# * 4 points

# %% [markdown]
# ### Question 5. In the United States as of 1995, minor is generally legally defined as a person under the age of 18. Write a code to check a student is minor or not. Verify the code by user input
# * 6 points

# %% [markdown]
# ### Question 7. Get a user input and check the given number is multiple of 11 or not
# * 5 points

# %% [markdown]
# ### Question 8. Convert the lists to dictionary
# * keys =  [10, 20, 30]
# * values =['Ten', 'Twenty', 'Thirty']
# * 4 points

# %% [markdown]
# ### Question 9. Write a function that can take `any arbitary numbers` as inputs and calculate the average of them. Check the function for two sets of inputs.
# * 2+2 points

# %% [markdown]
# ### Question 10. Write functions to find out Area of a right angle triangle. Check the result for base= 10, height =6.
# ![image.png](attachment:image.png)
#
# * 5 points

# %% [markdown]
# ### Question 11. Write down a program using while loop that prints all of the number from 10 to 20 (included). Repeat the number print using For loop.
# * 3+3 points

# %% [markdown]
# ### Question 12. Use inheritance to create the `square` class from parent class `rectangle`
# * 5 points

# %% [markdown]
# ## Extra: Fill up the course evaluation to get 4 bonus points.
